# %% [markdown]
# <a href="https://colab.research.google.com/github/charita07/retail_store_sales/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file = '/content/drive/MyDrive/Python notes/Data sheet/retail_store_sales.csv'
df=pd.read_csv(file)
df
# Out:
#       Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0        TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1        TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2        TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3        TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4        TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# ...              ...         ...            ...           ...             ...
# 12570    TXN_9347481     CUST_18     Patisserie   Item_23_PAT            38.0
# 12571    TXN_4009414     CUST_03      Beverages    Item_2_BEV             6.5
# 12572    TXN_5306010     CUST_11       Butchers    Item_7_BUT            14.0
# 12573    TXN_5167298     CUST_04      Furniture    Item_7_FUR            14.0
# 12574    TXN_2407494     CUST_23           Food   Item_9_FOOD            17.0
#
# ...

# %%
df.head(10)
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
# 5    TXN_7482416     CUST_09     Patisserie           NaN             NaN
# 6    TXN_3652209     CUST_07           Food   Item_1_FOOD             5.0
# 7    TXN_1372952     CUST_21      Furniture           NaN            33.5
# 8    TXN_9728486     CUST_23      Furniture   Item_16_FUR            27.5
# 9    TXN_2722661     CUST_25       Butchers   Item_22_BUT            36.5
#
#    Quantity  Total Spent  Payment Method  Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet    Online       2024-04-08
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12575 entries, 0 to 12574
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    12575 non-null  object
#  1   Customer ID       12575 non-null  object
#  2   Category          12575 non-null  object
#  3   Item              11362 non-null  object
#  4   Price Per Unit    11966 non-null  float64
#  5   Quantity          11971 non-null  float64
#  6   Total Spent       11971 non-null  float64
#  7   Payment Method    12575 non-null  object
#  8   Location          12575 non-null  object
#  9   Transaction Date  12575 non-null  object
#  10  Discount Applied  8376 non-null   object
# dtypes: float64(3), object(8)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#        Price Per Unit      Quantity   Total Spent
# count    11966.000000  11971.000000  11971.000000
# mean        23.365912      5.536380    129.652577
# std         10.743519      2.857883     94.750697
# min          5.000000      1.000000      5.000000
# 25%         14.000000      3.000000     51.000000
# 50%         23.000000      6.000000    108.500000
# 75%         33.500000      8.000000    192.000000
# max         41.000000     10.000000    410.000000

# %%
df.loc[0:20,['Customer ID','Category','Item','Price Per Unit']]
# Out:
#    Customer ID                       Category          Item  Price Per Unit
# 0      CUST_09                     Patisserie   Item_10_PAT            18.5
# 1      CUST_22                  Milk Products  Item_17_MILK            29.0
# 2      CUST_02                       Butchers   Item_12_BUT            21.5
# 3      CUST_06                      Beverages   Item_16_BEV            27.5
# 4      CUST_05                           Food   Item_6_FOOD            12.5
# 5      CUST_09                     Patisserie           NaN             NaN
# 6      CUST_07                           Food   Item_1_FOOD             5.0
# 7      CUST_21                      Furniture           NaN            33.5
# 8      CUST_23                      Furniture   Item_16_FUR            27.5
# 9      CUST_25                       Butchers   Item_22_BUT            36.5
# 10     CUST_22                       Butchers    Item_3_BUT             8.0
# ...

# %%
df.loc[:,['Category','Item','Total Spent','Discount Applied']]
# Out:
#             Category          Item  Total Spent Discount Applied
# 0         Patisserie   Item_10_PAT        185.0             True
# 1      Milk Products  Item_17_MILK        261.0             True
# 2           Butchers   Item_12_BUT         43.0            False
# 3          Beverages   Item_16_BEV        247.5              NaN
# 4               Food   Item_6_FOOD         87.5            False
# ...              ...           ...          ...              ...
# 12570     Patisserie   Item_23_PAT        152.0              NaN
# 12571      Beverages    Item_2_BEV         58.5            False
# 12572       Butchers    Item_7_BUT        140.0              NaN
# 12573      Furniture    Item_7_FUR         84.0             True
# 12574           Food   Item_9_FOOD         51.0              NaN
#
# [12575 rows x 4 columns]

# %%
large_spent = df[df['Total Spent']>150.0]
large_spent[['Customer ID','Category']]
# Out:
#       Customer ID                       Category
# 0         CUST_09                     Patisserie
# 1         CUST_22                  Milk Products
# 3         CUST_06                      Beverages
# 5         CUST_09                     Patisserie
# 13        CUST_14                     Patisserie
# ...           ...                            ...
# 12554     CUST_18                           Food
# 12557     CUST_24                      Beverages
# 12559     CUST_08                           Food
# 12560     CUST_20  Electric household essentials
# 12570     CUST_18                     Patisserie
#
# [4294 rows x 2 columns]

# %%
large_spent = df[df['Total Spent']<100.0]
df.head(5)
# Out:
#   Transaction ID Customer ID       Category          Item  Price Per Unit  \
# 0    TXN_6867343     CUST_09     Patisserie   Item_10_PAT            18.5
# 1    TXN_3731986     CUST_22  Milk Products  Item_17_MILK            29.0
# 2    TXN_9303719     CUST_02       Butchers   Item_12_BUT            21.5
# 3    TXN_9458126     CUST_06      Beverages   Item_16_BEV            27.5
# 4    TXN_4575373     CUST_05           Food   Item_6_FOOD            12.5
#
#    Quantity  Total Spent  Payment Method Location Transaction Date  \
# 0      10.0        185.0  Digital Wallet   Online       2024-04-08
# 1       9.0        261.0  Digital Wallet   Online       2023-07-23
# 2       2.0         43.0     Credit Card   Online       2022-10-05
# 3       9.0        247.5     Credit Card   Online       2022-05-07
# 4       7.0         87.5  Digital Wallet   Online       2022-10-02
#
#   Discount Applied
# 0             True
# 1             True
# 2            False
# 3              NaN
# ...
